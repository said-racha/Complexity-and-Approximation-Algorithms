# %%
from Graphe import *
from MethodesApprochees import *
from SeparationEvaluation import *
from Tests import *

# %% [markdown]
# # Evaluation du temps d'execution

# %%
inst_max = 21         #instance de taille maximale
pas = inst_max//10
if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
   
n=2                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}

# %%
########## Evaluation - Temps d'execution - Glouton et Couplage #########

#p=0.2
p=0.5
#p=0.7
temps_Glouton = calculerTemps(algo_glouton, tailles, p, n)
temps_Couplage = calculerTemps(algo_couplage, tailles, p, n)

temps_Couplage=list(np.where(np.array(temps_Couplage)==0,10**(-5), temps_Couplage))
temps_Glouton=list(np.where(np.array(temps_Glouton)==0,10**(-5), temps_Glouton))

#Quand on a plusieurs courbes, il faut avoir un nparray, quand on a un seul log, elle doit etre une liste
temps= np.array([temps_Glouton, temps_Couplage])
temps_log = np.array([np.log(temps_Glouton), np.log(temps_Couplage)])


dessinerGraphe(tailles, temps, 'Taille de l\'instance', "Temps moyen", "Evolution du temps de calcul en fonction de la taille de l'instance", nom_fichier='temps_couplage_glouton_p='+str(p)+"_n="+str(tailles[-1]))
dessinerGraphe(list(np.log(tailles)), temps_log, 'Logs Taille de l\'instance', 'Logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLog_couplage_glouton_p='+str(p)+"_n="+str(tailles[-1]))

#sauvegarder les données
nom_fichier='temps_couplage_glouton_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, temps)

# %%
########## Calcul - Complexités polynomiales ##########
calculerComplexitePoly(tailles, temps_Glouton)
calculerComplexitePoly(tailles, temps_Couplage)
# Out:
# complexite en O(n**3.79))
# complexite en O(n**2.47))

# %%
########## Evaluation 3D - Temps d'execution - Glouton et Couplage #########

# creer la plage de valeurs de n et p
n_values = np.arange(2, 101, 10)  
p_values = np.linspace(0.1, 0.9, 10)  

dessinerGraphe3D(n_values, p_values, algo_couplage, 'T')
dessinerGraphe3D(n_values, p_values, algo_glouton, 'T')

# %%
########## Evaluation - Temps d'execution - Branchement #########-

inst_max = 16         #instance de taille maximale
pas = inst_max//10

if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
    
n=6                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}
p=-1                 #executer la proba à 1/sqtr(n)

tempsBranchement= calculerTemps(branchement, tailles, p, n)
tempsBranchement=list(np.where(np.array(tempsBranchement)==0,10**(-5), tempsBranchement))

#print(tempsBranchement)
#print(tailles)

if(p!=-1):
    dessinerGraphe(tailles, tempsBranchement, 'Taille de l\'instance', 'Temps moyen', "Evolution du temps moyen d'execution en fonction de la taille de l'instance", nom_fichier='temps_branchement_p='+str(p)+"_n="+str(tailles[-1]), labels="Branchement")
    dessinerGraphe(tailles, list(np.log(tempsBranchement)), 'tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLog_branchement_p='+str(p)+"_n="+str(tailles[-1]), labels="Branchement")
else:
    dessinerGraphe(tailles, tempsBranchement, 'Taille de l\'instance', 'Temps moyen', "Evolution du temps moyen d'execution en fonction de la taille de l'instance", nom_fichier='temps_branchement_p=1sqrt(n)_n='+str(tailles[-1]), labels="Branchement")
    dessinerGraphe(tailles, list(np.log(tempsBranchement)), 'tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLog_branchement_p=1sqrt(n)_n='+str(tailles[-1]), labels="Branchement")

#sauvegarder les données
nom_fichier='temps_branchement_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, tempsBranchement)

#calculer la complexité
calculerComplexiteExpo(tailles, tempsBranchement)
# Out:
# complexite en O(2.72**x)

# %%
########## Evaluation - Temps d'execution - Branchement_avecBornes #########-

inst_max = 16         #instance de taille maximale
pas = inst_max//10

if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
    
n=4                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance
p=-1                 #executer la proba à 1/sqtr(n)

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}

tempsBranchement_avecBornes = calculerTemps(branchement_avecBornes, tailles, p, n)
tempsBranchement_avecBornes=list(np.where(np.array(tempsBranchement_avecBornes)==0,10**(-5), tempsBranchement_avecBornes))

#print(tempsBranchement_avecBornes)
#print(tailles)

labels="Branchement avec bornes"
if(p!=-1):
    dessinerGraphe(tailles, tempsBranchement_avecBornes, 'Taille de l\'instance', 'Temps moyen', "Evolution du temps moyen d'execution en fonction de la taille de l'instance", nom_fichier='temps_branchementAvecBornes_p='+str(p)+"_n="+str(tailles[-1]), labels=labels )
    dessinerGraphe(tailles, list(np.log(tempsBranchement_avecBornes)), 'tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLog_branchementAvecBornes_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)

else:
    dessinerGraphe(tailles, tempsBranchement_avecBornes, 'Taille de l\'instance', 'Temps moyen', "Evolution du temps moyen d'execution en fonction de la taille de l'instance", nom_fichier='temps_branchementAvecBornes_p=1sqrt(n)_n='+str(tailles[-1]),labels=labels )
    dessinerGraphe(tailles, list(np.log(tempsBranchement_avecBornes)), 'tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLog_branchementAvecBornes_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)

#sauvegarder les données    
nom_fichier='temps_branchementAvecBornes_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, tempsBranchement_avecBornes)

#calculer la complexité
calculerComplexiteExpo(tailles, tempsBranchement_avecBornes)
# Out:
# complexite en O(2.75**x)

# %%
########## Evaluation - Temps d'execution - Branchement_ameliore #########

inst_max = 71         #instance de taille maximale
pas = inst_max//10

if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
    
n=10                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance
p=-1                 #executer la proba à 1/sqtr(n)

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}

tempsBranchement_ameliore= calculerTemps(branchement_ameliore, tailles, p, n)
tempsBranchement_ameliore=list(np.where(np.array(tempsBranchement_ameliore)==0,10**(-5), tempsBranchement_ameliore))

#print(tempsBranchement_ameliore)
#print(tailles)

labels="Branchement ameliore"
if(p!=-1):
    dessinerGraphe(tailles, tempsBranchement_ameliore, 'Taille de l\'instance', 'Temps moyen', "Evolution du temps moyen d'execution en fonction de la taille de l'instance", nom_fichier='temps_branchementAmeliore_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(tempsBranchement_ameliore)), 'tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLogExpo_branchementAmeliore_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    dessinerGraphe(list(np.log(tailles)), list(np.log(tempsBranchement_ameliore)), 'logs tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLogPoly_branchementAmeliore_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)

else:
    dessinerGraphe(tailles, tempsBranchement_ameliore, 'Taille de l\'instance', 'Temps moyen', "Evolution du temps moyen d'execution en fonction de la taille de l'instance", nom_fichier='temps_branchementAmeliore_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(tempsBranchement_ameliore)), 'tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLogExpo_branchementAmeliore_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)
    dessinerGraphe(list(np.log(tailles)), list(np.log(tempsBranchement_ameliore)), 'logs tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLogPoly_branchementAmeliore_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)

#sauvegarder les données        
nom_fichier='temps_branchementAmeliore_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, tempsBranchement_ameliore)

#calculer la complexité
calculerComplexiteExpo(tailles, tempsBranchement_ameliore)
calculerComplexitePoly(tailles, tempsBranchement_ameliore)
# Out:
# complexite en O(1.19**x)
# complexite en O(n**5.06))

# %%
########## Evaluation - Temps d'execution - Branchement_ameliore_maxDeg #########

inst_max = 71         #instance de taille maximale
pas = inst_max//10

if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
    
n=10                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance
p=-1                 #executer la proba à 1/sqtr(n)

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}

tempsBranchement_ameliore_maxDeg= calculerTemps(branchement_ameliore_maxDeg, tailles, p, n)
tempsBranchement_ameliore_maxDeg=list(np.where(np.array(tempsBranchement_ameliore_maxDeg)==0,10**(-5), tempsBranchement_ameliore_maxDeg))

#print(tempsBranchement_ameliore_maxDeg)
#print(tailles)

labels="Branchement ameliore maxDeg"

if(p!=-1):
    dessinerGraphe(tailles, tempsBranchement_ameliore_maxDeg, 'Taille de l\'instance', 'Temps moyen', "Evolution du temps moyen d'execution en fonction de la taille de l'instance", nom_fichier='temps_branchementAmelioreMaxD_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(tempsBranchement_ameliore_maxDeg)), 'tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLogExpo_branchementAmelioreMaxD_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    dessinerGraphe(list(np.log(tailles)), list(np.log(tempsBranchement_ameliore_maxDeg)), 'logs tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLogPoly_branchementAmelioreMaxD_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)

else:
    dessinerGraphe(tailles, tempsBranchement_ameliore_maxDeg, 'Taille de l\'instance', 'Temps moyen', "Evolution du temps moyen d'execution en fonction de la taille de l'instance", nom_fichier='temps_branchementAmelioreMaxD_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(tempsBranchement_ameliore_maxDeg)), 'tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLogExpo_branchementAmelioreMaxD_p=1sqrt(n)_n='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    dessinerGraphe(list(np.log(tailles)), list(np.log(tempsBranchement_ameliore_maxDeg)), 'logs tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLogPoly_branchementAmelioreMaxD_p=1sqrt(n)_n='+str(p)+"_n="+str(tailles[-1]), labels=labels)

#sauvegarder les données            
nom_fichier='temps_branchementAmelioreMaxD_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, tempsBranchement_ameliore_maxDeg)

#calculer la complexité
calculerComplexiteExpo(tailles, tempsBranchement_ameliore_maxDeg)
calculerComplexitePoly(tailles, tempsBranchement_ameliore_maxDeg)
# Out:
# complexite en O(1.16**x)
# complexite en O(n**4.53))

# %%
########## Evaluation - Temps d'execution - heuristique_branchementAvecBornes #########

inst_max = 26         #instance de taille maximale
pas = inst_max//10

if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
    
n=10                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance
p=-1                 #executer la proba à 1/sqtr(n)

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}

tempsHeuristique= calculerTemps(heuristique_branchementAvecBornes, tailles, p, n)
tempsHeuristique=list(np.where(np.array(tempsHeuristique)==0,10**(-5), tempsHeuristique))

#print(tempsHeuristique)
#print(tailles)

labels="Heuristique"

if(p!=-1):
    dessinerGraphe(tailles, tempsHeuristique, 'Taille de l\'instance', 'Temps moyen', "Evolution du temps moyen d'execution en fonction de la taille de l'instance", nom_fichier='temps_Heuristique_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(tempsHeuristique)), 'tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLog_Heuristique_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)

else:
    dessinerGraphe(tailles, tempsHeuristique, 'Taille de l\'instance', 'Temps moyen', "Evolution du temps moyen d'execution en fonction de la taille de l'instance", nom_fichier='temps_Heuristique_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(tempsHeuristique)), 'tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLog_Heuristique_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)

#sauvegarder les données            
nom_fichier='temps_Heuristique_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, tempsHeuristique)
 
#calculer la complexité
calculerComplexiteExpo(tailles, tempsHeuristique)
calculerComplexitePoly(tailles, tempsHeuristique)
# Out:
# complexite en O(1.77**x)
# complexite en O(n**5.5))

# %%
########## Evaluation - Temps d'execution - heuristique_ameliore #########

inst_max = 26         #instance de taille maximale
pas = inst_max//10

if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
    
n=10                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance
p=-1                 #executer la proba à 1/sqtr(n)

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}

tempsHeuristiqueAmeliore= calculerTemps(heuristique_amelioree, tailles, p, n)
tempsHeuristiqueAmeliore=list(np.where(np.array(tempsHeuristiqueAmeliore)==0,10**(-5), tempsHeuristiqueAmeliore))

#print(tempsHeuristiqueAmeliore)
#print(tailles)

labels="Heuristique ameliore"

if(p!=-1):
    dessinerGraphe(tailles, tempsHeuristiqueAmeliore, 'Taille de l\'instance', 'Temps moyen', "Evolution du temps moyen d'execution en fonction de la taille de l'instance", nom_fichier='temps_HeuristiqueAmeliore_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(tempsHeuristiqueAmeliore)), 'tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLog_HeuristiqueAmeliore_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)

else:
    dessinerGraphe(tailles, tempsHeuristiqueAmeliore, 'Taille de l\'instance', 'Temps moyen', "Evolution du temps moyen d'execution en fonction de la taille de l'instance", nom_fichier='temps_HeuristiqueAmeliore_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(tempsHeuristiqueAmeliore)), 'tailles des instances', 'logs des temps moyens', 'Log du temps en fonction des tailles', log=True, nom_fichier='tempsLog_HeuristiqueAmeliore_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)

#sauvegarder les données            
nom_fichier='temps_HeuristiqueAmeliore_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, tempsHeuristiqueAmeliore)
 
#calculer la complexité
calculerComplexiteExpo(tailles, tempsHeuristiqueAmeliore)
calculerComplexitePoly(tailles, tempsHeuristiqueAmeliore)
# Out:
# complexite en O(1.49**x)
# complexite en O(n**3.8))

# %% [markdown]
# # Evaluation de la qualité de la solution

# %%
########## Evaluation - Taille couverture - Glouton et Couplage #########-
inst_max = 151         #instance de taille maximale
pas = inst_max//10
if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
   
n=10                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}
#p=0.2
p=0.5
#p=0.7
tailleCouverture_couplage= calculerTailleCouverture(algo_couplage, tailles, p, n)
tailleCouverture_glouton= calculerTailleCouverture(algo_glouton, tailles, p, n)

taillesCouvertures= np.array([tailleCouverture_glouton, tailleCouverture_couplage])

dessinerGraphe(tailles, taillesCouvertures, 'Taille de l\'instance', "Taille de la couverture", "Taille de la couverture en fonction de la taille de l'instance", nom_fichier='qualite_couplage_glouton_p='+str(p)+"_n="+str(tailles[-1]))

#sauvegarder les données
nom_fichier='qualite_couplage_glouton_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, taillesCouvertures)

# %%
########## Evaluation 3D - Taille couverture - Glouton et Couplage #########

# creer la plage de valeurs de n et p
n_values = np.arange(2, 101, 10)  
p_values = np.linspace(0.1, 0.9, 10)  

dessinerGraphe3D(n_values, p_values, algo_couplage, 'Q')
dessinerGraphe3D(n_values, p_values, algo_glouton, 'Q')

# %% [markdown]
# # Evaluation du nombre de noeuds générés

# %%
########## Evaluation - nombre de noeuds parcourus - Branchement #########-

inst_max = 16         #instance de taille maximale
pas = inst_max//10

if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
    
n=6                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}
p=-1                 #executer la proba à 1/sqtr(n)

nbNoeudsBranchement= calculerNbNoeuds(branchement, tailles, p, n)

#print(nbNoeudsBranchement)
#print(tailles)

if(p!=-1):
    dessinerGraphe(tailles, nbNoeudsBranchement, 'Taille de l\'instance', 'Nombre de noeuds', "Evolution du nombre de noeuds générés en fonction de la taille de l'instance", nom_fichier='nbNoeuds_branchement_p='+str(p)+"_n="+str(tailles[-1]), labels="Branchement")
    dessinerGraphe(tailles, list(np.log(nbNoeudsBranchement)), 'Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='Log_nbNoeuds_branchement_p='+str(p)+"_n="+str(tailles[-1]), labels="Branchement")

else:
    dessinerGraphe(tailles, nbNoeudsBranchement, 'Taille de l\'instance', 'Nombre de noeuds', "Evolution du nombre de noeuds générés en fonction de la taille de l'instance", nom_fichier='nbNoeuds_branchement_p=1sqrt(n)_n='+str(tailles[-1]), labels="Branchement")
    dessinerGraphe(tailles, list(np.log(nbNoeudsBranchement)), 'Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='Log_nbNoeuds_branchement_p=1sqrt(n)_n='+str(tailles[-1]), labels="Branchement")

#sauvegarder les données
nom_fichier='nbNoeuds_branchement_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, nbNoeudsBranchement)

#calculer la complexité
calculerComplexiteExpo(tailles, nbNoeudsBranchement)
# Out:
# complexite en O(2.05**x)

# %%
########## Evaluation - nombre de noeuds parcourus - Branchement avec bornes #########

inst_max = 16         #instance de taille maximale
pas = inst_max//10

if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
    
n=4                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}
p=-1                 #executer la proba à 1/sqtr(n)

nbNoeudsBranchement= calculerNbNoeuds(branchement_avecBornes, tailles, p, n)

#print(nbNoeudsBranchement)
#print(tailles)

if(p!=-1):
    dessinerGraphe(tailles, nbNoeudsBranchement, 'Taille de l\'instance', 'Nombre de noeuds', "Evolution du nombre de noeuds générés en fonction de la taille de l'instance", nom_fichier='nbNoeuds_branchement_avecBornes_p='+str(p)+"_n="+str(tailles[-1]), labels="Branchement avec bornes")
    dessinerGraphe(tailles, list(np.log(nbNoeudsBranchement)), 'Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='Log_nbNoeuds_branchement_avecBornes_p='+str(p)+"_n="+str(tailles[-1]), labels="Branchement avec bornes")

else:
    dessinerGraphe(tailles, nbNoeudsBranchement, 'Taille de l\'instance', 'Nombre de noeuds', "Evolution du nombre de noeuds générés en fonction de la taille de l'instance", nom_fichier='nbNoeuds_branchement_avecBornes_p=1sqrt(n)_n='+str(tailles[-1]), labels="Branchement avec bornes")
    dessinerGraphe(tailles, list(np.log(nbNoeudsBranchement)), 'Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='Log_nbNoeuds_branchement_avecBornes_p=1sqrt(n)_n='+str(tailles[-1]), labels="Branchement avec bornes")

#sauvegarder les données
nom_fichier='nbNoeuds_branchement_avecBornes_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, nbNoeudsBranchement)

#calculer la complexité
calculerComplexiteExpo(tailles, nbNoeudsBranchement)
# Out:
# complexite en O(2.05**x)

# %%
########## Evaluation - nombre de noeuds parcourus - Branchement ameliore #########

inst_max = 51         #instance de taille maximale
pas = inst_max//10

if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
    
n=10                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}
p=-1                 #executer la proba à 1/sqtr(n)

nbNoeudsBranchement= calculerNbNoeuds(branchement_ameliore, tailles, p, n)

#print(nbNoeudsBranchement)
#print(tailles)

labels="Branchement ameliore"

if(p!=-1):
    dessinerGraphe(tailles, nbNoeudsBranchement, 'Taille de l\'instance', 'Nombre de noeuds', "Evolution du nombre de noeuds générés en fonction de la taille de l'instance", nom_fichier='nbNoeuds_branchement_ameliore_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(nbNoeudsBranchement)), 'Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='LogExpo_nbNoeuds_branchement_ameliore_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    dessinerGraphe(list(np.log(tailles)), list(np.log(nbNoeudsBranchement)), 'Log Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='LogPoly_nbNoeuds_branchement_ameliore_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)

else:
    dessinerGraphe(tailles, nbNoeudsBranchement, 'Taille de l\'instance', 'Nombre de noeuds', "Evolution du nombre de noeuds générés en fonction de la taille de l'instance", nom_fichier='nbNoeuds_branchement_ameliore_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(nbNoeudsBranchement)), 'Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='LogExpo_nbNoeuds_branchement_ameliore_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)
    dessinerGraphe(list(np.log(tailles)), list(np.log(nbNoeudsBranchement)), 'Log Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='LogPoly_nbNoeuds_branchement_ameliore_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)

#sauvegarder les données
nom_fichier='nbNoeuds_branchement_ameliore_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, nbNoeudsBranchement)

#calculer la complexité
calculerComplexiteExpo(tailles, nbNoeudsBranchement)
calculerComplexitePoly(tailles, nbNoeudsBranchement)
# Out:
# complexite en O(1.11**x)
# complexite en O(n**2.13))

# %%
########## Evaluation - nombre de noeuds parcourus - Branchement ameliore maxDeg #########

inst_max = 51         #instance de taille maximale
pas = inst_max//10

if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
    
n=10                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}
p=-1                 #executer la proba à 1/sqtr(n)

nbNoeudsBranchement= calculerNbNoeuds(branchement_ameliore_maxDeg, tailles, p, n)

#print(nbNoeudsBranchement)
#print(tailles)

labels="Branchement ameliore maxDeg"

if(p!=-1):
    dessinerGraphe(tailles, nbNoeudsBranchement, 'Taille de l\'instance', 'Nombre de noeuds', "Evolution du nombre de noeuds générés en fonction de la taille de l'instance", nom_fichier='nbNoeuds_branchement_ameliore_maxDeg_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(nbNoeudsBranchement)), 'Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='LogExpo_nbNoeuds_branchement_ameliore_maxDeg_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    dessinerGraphe(list(np.log(tailles)), list(np.log(nbNoeudsBranchement)), 'Log Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='LogPoly_nbNoeuds_branchement_ameliore_maxDeg_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)

else:
    dessinerGraphe(tailles, nbNoeudsBranchement, 'Taille de l\'instance', 'Nombre de noeuds', "Evolution du nombre de noeuds générés en fonction de la taille de l'instance", nom_fichier='nbNoeuds_branchement_ameliore_maxDeg_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(nbNoeudsBranchement)), 'Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='LogExpo_nbNoeuds_branchement_ameliore_maxDeg_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)
    dessinerGraphe(list(np.log(tailles)), list(np.log(nbNoeudsBranchement)), 'Log Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='LogPoly_nbNoeuds_branchement_ameliore_maxDeg_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)

#sauvegarder les données
nom_fichier='nbNoeuds_branchement_ameliore_maxDeg_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, nbNoeudsBranchement)

#calculer la complexité
calculerComplexiteExpo(tailles, nbNoeudsBranchement)
calculerComplexitePoly(tailles, nbNoeudsBranchement)
# Out:
# complexite en O(1.1**x)
# complexite en O(n**2.09))

# %%
########## Evaluation - nombre de noeuds parcourus - Heuristique #########

inst_max = 21         #instance de taille maximale
pas = inst_max//10

if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
    
n=7                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}
p=-1                 #executer la proba à 1/sqtr(n)

nbNoeudsBranchement= calculerNbNoeuds(heuristique_branchementAvecBornes, tailles, p, n)

#print(nbNoeudsBranchement)
#print(tailles)

labels="Heuristique"

if(p!=-1):
    dessinerGraphe(tailles, nbNoeudsBranchement, 'Taille de l\'instance', 'Nombre de noeuds', "Evolution du nombre de noeuds générés en fonction de la taille de l'instance", nom_fichier='nbNoeuds_heuristique_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(nbNoeudsBranchement)), 'Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='LogExpo_nbNoeuds_heuristique_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    
else:
    dessinerGraphe(tailles, nbNoeudsBranchement, 'Taille de l\'instance', 'Nombre de noeuds', "Evolution du nombre de noeuds générés en fonction de la taille de l'instance", nom_fichier='nbNoeuds_heuristique_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(nbNoeudsBranchement)), 'Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='LogExpo_nbNoeuds_heuristique_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)
    
#sauvegarder les données
nom_fichier='nbNoeuds_heuristique_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, nbNoeudsBranchement)

#calculer la complexité
calculerComplexiteExpo(tailles, nbNoeudsBranchement)
# Out:
# complexite en O(1.46**x)

# %%
########## Evaluation - nombre de noeuds parcourus - Heuristique ameliore #########

inst_max = 31         #instance de taille maximale
pas = inst_max//10

if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
    
n=10                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}
p=-1                 #executer la proba à 1/sqtr(n)

nbNoeudsBranchement= calculerNbNoeuds(heuristique_amelioree, tailles, p, n)

#print(nbNoeudsBranchement)
#print(tailles)

labels="Heuristique amelioree"

if(p!=-1):
    dessinerGraphe(tailles, nbNoeudsBranchement, 'Taille de l\'instance', 'Nombre de noeuds', "Evolution du nombre de noeuds générés en fonction de la taille de l'instance", nom_fichier='nbNoeuds_heuristique_amelioree_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(nbNoeudsBranchement)), 'Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='LogExpo_nbNoeuds_heuristique_amelioree_p='+str(p)+"_n="+str(tailles[-1]), labels=labels)
    
else:
    dessinerGraphe(tailles, nbNoeudsBranchement, 'Taille de l\'instance', 'Nombre de noeuds', "Evolution du nombre de noeuds générés en fonction de la taille de l'instance", nom_fichier='nbNoeuds_heuristique_amelioree_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)
    dessinerGraphe(tailles, list(np.log(nbNoeudsBranchement)), 'Taille de l\'instance', 'Logs du nombre de noeuds', 'Log du nombre de noeuds en fonction des tailles', log=True, nom_fichier='LogExpo_nbNoeuds_heuristique_amelioree_p=1sqrt(n)_n='+str(tailles[-1]), labels=labels)
    
#sauvegarder les données
nom_fichier='nbNoeuds_heuristique_amelioree_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, nbNoeudsBranchement)

#calculer la complexité
calculerComplexiteExpo(tailles, nbNoeudsBranchement)
# Out:
# complexite en O(1.26**x)

# %% [markdown]
# # Evaluation du rapport d'approximation

# %%
########## Evaluation - Rapport d'approximation - Glouton et Couplage #########
p=0.2
#p=0.5
#p=0.7

inst_max = 31         #instance de taille maximale
pas = inst_max//10
if(pas>1):
    inst_min = pas        #instance de taille minimale, dans notre cas elle est egale au pas (inst_max/10)
else:
    inst_min =2
 
n=6                  #nombre de tests pour avoir le temps moyen d'une seule taille d'instance

tailles = [i for i in range(inst_min, inst_max, pas)]   #des tailles appartenant a {inst_max/10, 2*inst_max/10, .... , inst_max}
rapports_approximations_glouton= calculerRapportApproximation(algo_glouton, tailles, p, n)
rapports_approximations_couplage= calculerRapportApproximation(algo_couplage, tailles, p, n)

rapports_approximations= np.array([rapports_approximations_glouton, rapports_approximations_couplage])

if(p!=-1):
    dessinerGraphe(tailles, rapports_approximations, 'Taille de l\'instance', "Taille de la couverture", "Taille de la couverture en fonction de la taille de l'instance", nom_fichier='rapportAapproximation_glouton_couplage_p='+str(p)+"_n="+str(tailles[-1]))
else:
    dessinerGraphe(tailles, rapports_approximations, 'Taille de l\'instance', "Taille de la couverture", "Taille de la couverture en fonction de la taille de l'instance", nom_fichier='rapportAapproximation_glouton_couplage_p=1sqrt(n)_n='+str(tailles[-1]))

#sauvegarder les données  
nom_fichier='rapportAapproximation_glouton_couplage_p='+str(p)+"_n="+str(tailles[-1])
sauvegarderDonnes(nom_fichier, tailles, rapports_approximations)

#afficher les pire rapport d'approximation 
print("le pire rapport d'approximation de Glouton: ", np.max(np.round(rapports_approximations_glouton,2)))
print("le pire rapport d'approximation de Couplage: ", np.max(np.round(rapports_approximations_couplage,2)))
# Out:
# le pire rapport d'approximation de Glouton:  1.08
# le pire rapport d'approximation de Couplage:  2.0
